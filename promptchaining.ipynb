# %%
from langgraph.graph import StateGraph,START,END    
from langchain_ollama import ChatOllama
from typing import TypedDict

# %%
model = ChatOllama(model="tinyllama")

# %%
class BlogState(TypedDict):
    title: str
    outline: str
    content: str

# %%
def create_outline(state: BlogState) -> BlogState:
    title = state['title']
    prompt = f"Generate an outline for a blog post titled: {title}"
    outline = model.invoke(prompt).content

    state['outline'] = outline

    return state

# %%
def create_blog(state: BlogState) -> BlogState:
    title = state['title']
    outline = state['outline']
    prompt = f'Write a detailed blog on the title - {title} using the following outline \n {outline}'
    content = model.invoke(prompt).content

    state['content'] = content

    return state

# %%
graph = StateGraph(BlogState)


graph.add_node('create_outline', create_outline)
graph.add_node('create_blog', create_blog)


graph.add_edge(START,'create_outline')
graph.add_edge('create_outline','create_blog')
graph.add_edge('create_blog',END)


workflow = graph.compile()

# %%
initial_state = { 'title': "The Future of AI in Everyday Life" }
final_state = workflow.invoke(initial_state)
final_state['content']
# Out:
# 'Title: The Future of AI in Everyday Life\n\nExecutive Summary:\n\nIn recent years, the advancements in Artificial Intelligence (AI) have led to significant changes in our everyday lives. From enhanced smart homes and smart appliaces to voice-activated assistants and self-driving cars, AI is transforming various industries and making life easier for people. In this blog post, we\'ll explore the impact of AI on different aspects of our daily lives and how these changes will continue to shape our world in the future.\n\nChapter 1: Smart Home Systems and Robotic Assistant\n\nOne of the most notable applications of AI in daily life is in smart homes and smart appliaces. These devices are programmed with artificial intelligence to monitor the environment and make adjustments accordingly. According to a report by Global Market Insights, the market for smart home systems is projected to grow from $10 billion in 2019 to $45 billion by 2026 at a compound annual growth rate of 37%. This growth can be attributed to the advancements in AI-powered platforms and sensor technology, which are designed to provide homeowners with more efficient and personalized experiences.\n\nChapter 2: Voice-Activated Assistant and Self-Driving Cars\n\nThe second area where AI is transforming daily life is through voice-activated assistant systems and self-driving cars. These devices use natural language processing (NLP) and machine learning algorithms to understand users\' requests and respond accordingly. For instance, Alexa and Siri are both developed by Amazon and Apple respectively, allowing users to make bookings, set reminders, and receive traffic updates through voice commands.\n\nThe rise of self-driving cars has also transformed our daily lives. These vehicles operate on their own without human intervention, making them safer and more efficient than conventional vehicles. According to a report by Frost & Sulivan, the global market for driverless car technology is expected to reach $46 billion in 2030, with AI being one of the key drivers.\n\nChapter 3: Enhanced Smart Appliaces and Robotic Assistant\n\nEnhancing smart appliaces and robotics systems is another area where AI is transforming our lives. These devices are often equipped with sensor technology, allowing them to interact with humans and the environment in real-time. For instance, LG\'s SmartThinQ platform allows users to control their home appliances using voice commands, while Coke has developed a robot named "Max" that delivers beverages to customers via robots.\n\nAccording to a report by Garner, the global market for smart homes and smart buildings is expected to reach $170 billion in 2024. This growth can be attributed to the increasing adoption of AI-powered platforms and sensor technology in these areas.\n\nConclusion:\n\nIn conclusion, AI is transforming various aspects of our daily lives, including smart homes and smart appliaces, voice-activated assistant systems, self-driving cars, and enhanced smart appliace systems. These changes are not limited to the technology industry but extend into various industries such as healthcare, banking, and transportation. As AI continues to evolve, we can expect even more innovations in these areas.'
